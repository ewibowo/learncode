# %% [markdown]
# Kth Smallest Element in a BST
#
# Solution
# Given the root of a binary search tree, and an integer k, return the kth smallest value (1-indexed) of all the values of the nodes in the tree.
#
# Example 1:
# ```
# Input: root = [3,1,4,null,2], k = 1
# Output: 1
# ```
# Example 2:
# ```
# Input: root = [5,3,6,2,4,null,null,1], k = 3
# Output: 3
# ```
#
# Constraints:
# ```
# The number of nodes in the tree is n.
# 1 <= k <= n <= 104
# 0 <= Node.val <= 104
# ```
#
#
# Follow up: If the BST is modified often (i.e., we can do insert and delete operations) and you need to find the kth smallest frequently, how would you optimize?

# %%
from typing import Optional

# Definition for a binary tree node
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:
        count = 0
        self.result = None
        
        def inorder(node):
            #if node is None or self.result is not None:
            if not node or self.result:
                return
            
            # Traverse left subtree
            inorder(node.left)
            
            # Process current node
            count += 1
            if count == k:
                self.result = node.val
                return
            
            # Traverse right subtree
            inorder(node.right)
        
        inorder(root)
        return self.result


# Test the solution
solution = Solution()

# Example 1: root = [3,1,4,null,2], k = 1
# Tree structure:
#     3
#    / \
#   1   4
#    \
#     2

print("Example 1:")
print("Tree structure:")
print("    3")
print("   / \\")
print("  1   4")
print("   \\")
print("    2")
print()

# Build the tree manually
root1 = TreeNode(3)
root1.left = TreeNode(1)
root1.right = TreeNode(4)
root1.left.right = TreeNode(2)

result1 = solution.kthSmallest(root1, 1)
print(f"Input: k = 1")
print(f"Output: {result1}")
print()


# Example 2: root = [5,3,6,2,4,null,null,1], k = 3
# Tree structure:
#       5
#      / \
#     3   6
#    / \
#   2   4
#  /
# 1

print("Example 2:")
print("Tree structure:")
print("      5")
print("     / \\")
print("    3   6")
print("   / \\")
print("  2   4")
print(" /")
print("1")
print()

# Build the tree manually
root2 = TreeNode(5)
root2.left = TreeNode(3)
root2.right = TreeNode(6)
root2.left.left = TreeNode(2)
root2.left.right = TreeNode(4)
root2.left.left.left = TreeNode(1)

result2 = solution.kthSmallest(root2, 3)
print(f"Input: k = 3")
print(f"Output: {result2}")
print()
# Out:
# Example 1:
# Tree structure:
#     3
#    / \
#   1   4
#    \
#     2
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 62
#      59 root1.right = TreeNode(4)
#      60 root1.left.right = TreeNode(2)
# ---> 62 result1 = solution.kthSmallest(root1, 1)
#      63 print(f"Input: k = 1")
#      64 print(f"Output: {result1}")
#
# Cell In[5], line 32, in Solution.kthSmallest(self, root, k)
#      29     # Traverse right subtree
#      30     inorder(node.right)
# ---> 32 inorder(root)
#      33 return self.result
#
# Cell In[5], line 21, in Solution.kthSmallest.<locals>.inorder(node)
#      18     return
#      20 # Traverse left subtree
# ---> 21 inorder(node.left)
#      23 # Process current node
#      24 count += 1
#
# Cell In[5], line 24, in Solution.kthSmallest.<locals>.inorder(node)
#      21 inorder(node.left)
#      23 # Process current node
# ---> 24 count += 1
#      25 if count == k:
#      26     self.result = node.val
#
# UnboundLocalError: cannot access local variable 'count' where it is not associated with a value
